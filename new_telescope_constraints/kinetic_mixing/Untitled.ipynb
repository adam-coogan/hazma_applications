# %%
from scipy.interpolate import interp1d
import numpy as np

# %%
xs = np.linspace(1,2,100)
ys = xs**2
interp = interp1d(xs, ys)

# %%
def g(x: float ):  
    """
    Return stuff
    
    Parameters
    ----------
    x: float
        Thing
    """
    return interp(x)

# %%
g.__dict__
# Out:
# {}

# %%
f(1.0)

# %%
interp.__dict__
# Out:
# {'bounds_error': True,
#  'copy': True,
#  'axis': 0,
#  'y': array([1.        , 1.02030405, 1.04081216, 1.06152433, 1.08244057,
#         1.10356086, 1.12488522, 1.14641363, 1.16814611, 1.19008264,
#         1.21222324, 1.2345679 , 1.25711662, 1.2798694 , 1.30282624,
#         1.32598714, 1.34935211, 1.37292113, 1.39669421, 1.42067136,
#         1.44485257, 1.46923783, 1.49382716, 1.51862055, 1.543618  ,
#         1.56881951, 1.59422508, 1.61983471, 1.6456484 , 1.67166616,
#         1.69788797, 1.72431385, 1.75094378, 1.77777778, 1.80481584,
#         1.83205795, 1.85950413, 1.88715437, 1.91500867, 1.94306703,
#         1.97132946, 1.99979594, 2.02846648, 2.05734109, 2.08641975,
#         2.11570248, 2.14518927, 2.17488011, 2.20477502, 2.23487399,
#         2.26517702, 2.29568411, 2.32639527, 2.35731048, 2.38842975,
#         2.41975309, 2.45128048, 2.48301194, 2.51494745, 2.54708703,
#         2.57943067, 2.61197837, 2.64473013, 2.67768595, 2.71084583,
# ...
